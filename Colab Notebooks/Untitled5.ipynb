# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone "https://github.com/rbgus17/2016732034_HW4.git"
# Out:
# Cloning into '2016732034_HW4'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 39 (delta 9), reused 26 (delta 7), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
cd 2016732034_HW4
# Out:
# /content/drive/MyDrive/2016732034_HW4

# %%
# !git checkout -b branch_pr_2016732005
# Out:
# Switched to a new branch 'branch_pr_2016732005'

# %%
# !git status
# Out:
# On branch branch_pr_2016732005
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
# * branch_pr_2016732005
#   main

# %%
# !git config --local user.email "rbgus123@gmail.com"
# !git config --local user.name "rbgus17"

# %%
# !git add .
# !git commit -m "Edit Readme.md by rbgus17"
# Out:
# [branch_pr_2016732005 5c65001] Edit Readme.md by rbgus17
#  1 file changed, 1 insertion(+)

# %%
# !git remote add fork1 https://rbgus17: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@github.com/rbgus17/2016732034_HW4.git
# Out:
# fatal: remote fork1 already exists.

# %%
# !git push -u fork1 branch_pr_2016732005
# Out:
# To https://github.com/rbgus17/2016732034_HW4.git
#  ! [rejected]        branch_pr_2016732005 -> branch_pr_2016732005 (non-fast-forward)
# error: failed to push some refs to 'https://rbgus17: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@github.com/rbgus17/2016732034_HW4.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

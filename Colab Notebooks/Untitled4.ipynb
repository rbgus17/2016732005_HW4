# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
mkdir temp
# Out:
# mkdir: cannot create directory ‘temp’: File exists

# %%
cd temp
# Out:
# /content/drive/MyDrive/temp

# %%
# !git clone "https://github.com/socity11nathan/2016732034_HW4.git"
# Out:
# Cloning into '2016732034_HW4'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 21 (delta 4), reused 10 (delta 2), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
cd 2016732034_HW4/
# Out:
# /content/drive/MyDrive/temp/2016732034_HW4

# %%
# !git config --local user.email "rbgus123@gmail.com"
# !git config --local user.name "rbgus17"

# %%
# !git add .
# !git commit -m "Edit Readme.md by rbgus17"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote add jin970 https://collaborator_rbgus17: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@github.com/socity11nathan/2016732034_HW4.git

# %%
# !git push -u jin970 main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'jin970'.
# Everything up-to-date

# %%
# !git checkout -b branch_pr
# Out:
# Switched to a new branch 'branch_pr'

# %%
# !git status
# Out:
# On branch branch_pr
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
# * branch_pr
#   main

# %%
# !git add .
# !git commit -m "Edit Readme.md in Branch_pr"
# Out:
# [branch_pr 0e8020f] Edit Readme.md in Branch_pr
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !git push jin970 branch_pr
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 295 bytes | 98.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/socity11nathan/2016732034_HW4.git
#    c7058aa..0e8020f  branch_pr -> branch_pr

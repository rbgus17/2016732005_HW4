# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone "https://github.com/rbgus17/2016732005_HW4.git"
# Out:
# Cloning into '2016732005_HW4'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 30 (delta 8), reused 23 (delta 6), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
cd 2016732005_HW4/
# Out:
# /content/drive/MyDrive/Colab Notebooks/2016732005_HW4

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/2016732005_HW4/.git/

# %%
# !git config --global user.email "rbgus123@gmail.com"
# !git config --global user.name "rbgus17"

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git log
# Out:
# commit 6992738cb116546118d5c64ba477156a15b578d5 (HEAD -> main, origin/main, origin/HEAD)
# Author: rbgus17 <114327044+rbgus17@users.noreply.github.com>
# Date:   Fri Sep 30 17:13:21 2022 +0900
#
#     Update README.md
#
# commit 37cc4aac12584f91071f6fca22cd69759bb28597
# Author: socity11nathan <jin970528@gmail.com>
# Date:   Fri Sep 30 07:11:19 2022 +0000
#
#     Edit Readme.md by socity11nathan
#
# commit 8f2832f9cd6fc8e2ce4885e02cf5eca676084224
# Author: rbgus17 <rbgus123@gmail.com>
# Date:   Fri Sep 30 06:46:20 2022 +0000
#
#     Edit Readme.md
#
# commit e2dd4a3041fde9f84587206291bc1e2421253251
# Author: rbgus17 <rbgus123@gmail.com>
# Date:   Thu Sep 29 06:30:36 2022 +0000
#
#     Edit Readme.md
#
# commit f14d9d42404fd10b1ac46c1f5d1e0a0df02aacc0
# Author: rbgus17 <rbgus123@gmail.com>
# Date:   Thu Sep 29 05:18:57 2022 +0000
#
#     Edit Readme.md
#
# commit accfc385fad07d62242f746e7b5b4be264830b41
# Author: rbgus17 <rbgus123@gmail.com>
# Date:   Mon Sep 26 05:49:30 2022 +0000
#
# ...

# %%
# !git remote add repo-basic https://rbgus17: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@github.com/rbgus17/2016732005_HW4.git

# %%
# !git push -u repo-basic main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'repo-basic'.
# Everything up-to-date

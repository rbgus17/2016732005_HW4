# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone "https://github.com/rbgus17/2016732005_HW4.git"
# Out:
# Cloning into '2016732005_HW4'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd 2016732005_HW4/
# Out:
# /content/drive/MyDrive/2016732005_HW4

# %%
# !git config --local user.email "rbgus123@gmail.com"
# !git config --local user.name "rbgus17"

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# [main b399a7f] Edit Readme.md
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
# !git remote add basic https://rbgus17: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@github.com/rbgus17/2016732005_HW4.git

# %%
# !git push -u basic main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 339 bytes | 84.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/rbgus17/2016732005_HW4.git
#    847d383..b399a7f  main -> main
# Branch 'main' set up to track remote branch 'main' from 'basic'.

# %%
# !git checkout -b branch_pr
# Out:
# Switched to a new branch 'branch_pr'

# %%
# !git status
# Out:
# On branch branch_pr
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
# * branch_pr
#   main

# %%
# !git add .
# !git commit -m "Edit Readme.md in branch_pr"
# Out:
# [branch_pr 8dd1879] Edit Readme.md in branch_pr
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push basic branch_pr
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 276 bytes | 138.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote:
# remote: Create a pull request for 'branch_pr' on GitHub by visiting:
# remote:      https://github.com/rbgus17/2016732005_HW4/pull/new/branch_pr
# remote:
# To https://github.com/rbgus17/2016732005_HW4.git
#  * [new branch]      branch_pr -> branch_pr

# %% [markdown]
# # Problem 2

# %%
# 변수 선언
name = a
age = b
grade = c

# 입출력 함수로 이름, 나이, 학점 나타내기
print('What is your name?')
a = input()
print(a)

print('How old are you?')
b = input()
print(b)

print('What is your grade point average?')
c = input()
print(c)

print('Your name is %s' % a)
print('Your age is %s' % b)
print('Your grade is %s' % c)
# Out:
# What is your name?
# Jeon
# Jeon
# How old are you?
# 27
# 27
# What is your grade point average?
# 4.2
# 4.2
# Your name is Jeon
# Your age is 27
# Your grade is 4.2

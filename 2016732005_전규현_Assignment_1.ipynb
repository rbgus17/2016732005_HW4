# %% [markdown]
# # 이미지 띄워보기

# %% [markdown]
# ![라이언](https://camo.githubusercontent.)

# %% [markdown]
# # 표 그리기

# %% [markdown]
# | 품목 | 단가 | 개수 | 금액 |
# | :------- | :----: | :---: | ------: |
# | 브로콜리 | 1,500 | 5 | 7,500 |
# | 가지 | 1,000 | 10 | 10,000 |
# | 아스파라거스 | 1,000 | 15 | 15,000 |

# %% [markdown]
# # 수식 표시

# %% [markdown]
# $$
# \begin{aligned}
# f(x)&=\int_{0}^{10} {2x^2+4x+6 \over x-2}\
# \end{aligned}
# $$
